# %% [markdown]
# # Detecção de Bots Dataset Telegram
#
# Assumimos que bots apresentam comportamento coordenado com outros usuários ou bots. Utilizando hipóteses de comportamento humano, serão criados grafos com candidatos a bots que serão filtrados usando algoritmos de comunidade. As hipóteses definidas foram:
#
# 1. Pessoas dificilmente compartilham mensagens poucos segundos após ser enviada
# 2. Pessoas dificilmente compartilham mensagens no mesmo horário frequentemente
# 3. Pessoas apresentam intervalos de tempo entre mensagens caóticos. Bots tendem a enviar mensagens de forma mais sistematizada

# %%
# dependências
import networkx as nx
from networkx.algorithms import community
import concurrent.futures
import os

import warnings
import os
os.chdir("..")
from util.load_graph import load_graph_by_edge, get_driver
from util.bot_filtering import rank_bot_suspicion

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
driver = get_driver()

# %% [markdown]
# ## Hipótese 1: Usuários que compartilham mensagens rápidos demais
#
# ![rapid share](../../images/rapid_share.png)

# %%
G_rapid = load_graph_by_edge(driver, 'RAPID_SHARE')

rapid_bots = rank_bot_suspicion(G_rapid) 
rapid_bots
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 3, column: 16, offset: 55} for query: '\n        MATCH (n)-[r:RAPID_SHARE]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 4, column: 16, offset: 121} for query: '\n        MATCH (n)-[r:RAPID_SHARE]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
#      user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 11     49273               0.6670           0.1674        1.0000
# 25     49291               0.5835           0.1259        0.9709
# 26     49351               0.5151           0.0772        1.0000
# 99     49575               0.4150           1.0000        0.0002
# 5      49272               0.2347           0.5513        0.0000
# ..       ...                  ...              ...           ...
# 85     53929               0.0092           0.0224        0.0000
# 156    55855               0.0089           0.0218        0.0000
# 343    52561               0.0085           0.0207        0.0000
# 121    49685               0.0079           0.0193        0.0000
# 27     51884               0.0050           0.0120        0.0000
#
#      volume_score labels
# 11         1.0000     []
# 25         0.7241     []
# 26         0.4212     []
# 99         0.0743     []
# 5          0.0709     []
# ..            ...    ...
# 85         0.0011     []
# 156        0.0011     []
# 343        0.0011     []
# 121        0.0011     []
# 27         0.0011     []
#
# [474 rows x 6 columns]

# %%
rapid_bots.describe()
# Out:
#             user_id  bot_suspicion_score  centrality_rank  clique_score  \
# count    474.000000           474.000000       474.000000    474.000000
# mean   52253.940928             0.036305         0.078912      0.007692
# std     3079.043486             0.051158         0.060814      0.078742
# min    49271.000000             0.005000         0.012000      0.000000
# 25%    49873.500000             0.020800         0.049025      0.000000
# 50%    51186.500000             0.031800         0.078900      0.000000
# 75%    53096.500000             0.034800         0.078900      0.000000
# max    59798.000000             0.667000         1.000000      1.000000
#
#        volume_score
# count    474.000000
# mean       0.008271
# std        0.060019
# min        0.001100
# 25%        0.001100
# 50%        0.002300
# 75%        0.003400
# max        1.000000

# %%
filtered_rapid_bots = rapid_bots[
    rapid_bots['bot_suspicion_score'] >
    rapid_bots['bot_suspicion_score'].quantile(0.7)
]
filtered_rapid_bots
# Out:
#      user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 11     49273               0.6670           0.1674        1.0000
# 25     49291               0.5835           0.1259        0.9709
# 26     49351               0.5151           0.0772        1.0000
# 99     49575               0.4150           1.0000        0.0002
# 5      49272               0.2347           0.5513        0.0000
# ..       ...                  ...              ...           ...
# 206    50228               0.0327           0.0800        0.0000
# 138    50285               0.0327           0.0788        0.0000
# 225    50398               0.0325           0.0673        0.0129
# 306    51522               0.0322           0.0771        0.0000
# 458    59623               0.0321           0.0790        0.0000
#
#      volume_score labels
# 11         1.0000     []
# 25         0.7241     []
# 26         0.4212     []
# 99         0.0743     []
# 5          0.0709     []
# ..            ...    ...
# 206        0.0034     []
# 138        0.0056     []
# 225        0.0023     []
# 306        0.0068     []
# 458        0.0023     []
#
# [137 rows x 6 columns]

# %% [markdown]
# ## Hipótese 2: Usuários que compartilham mensagens no mesmo horário frequentemente
#
# ![hourly](../../images/hourly.png)

# %%
G_hourly = load_graph_by_edge(driver, 'HOURLY_SHARED')

hourly_bots = rank_bot_suspicion(G_hourly) 
hourly_bots
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 3, column: 16, offset: 57} for query: '\n        MATCH (n)-[r:HOURLY_SHARED]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 4, column: 16, offset: 123} for query: '\n        MATCH (n)-[r:HOURLY_SHARED]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
#       user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 76      49273               0.6131           0.0327        1.0000
# 253     49351               0.5278           0.0201        0.9909
# 440     51656               0.4119           1.0000        0.0007
# 13      49575               0.3799           0.9319        0.0000
# 252     49291               0.3300           0.0226        0.4993
# ...       ...                  ...              ...           ...
# 1859    52517               0.0010           0.0025        0.0000
# 2072    54270               0.0010           0.0025        0.0000
# 826     49489               0.0010           0.0024        0.0000
# 2089    54633               0.0010           0.0026        0.0000
# 254     51884               0.0009           0.0024        0.0000
#
#       volume_score labels
# 76          1.0000     []
# 253         0.6171     []
# 440         0.0579     []
# 13          0.0357     []
# 252         0.6058     []
# ...            ...    ...
# 1859        0.0000     []
# 2072        0.0000     []
# 826         0.0000     []
# 2089        0.0000     []
# 254         0.0000     []
#
# [2413 rows x 6 columns]

# %%
hourly_bots.describe()
# Out:
#             user_id  bot_suspicion_score  centrality_rank  clique_score  \
# count   2413.000000          2413.000000      2413.000000   2413.000000
# mean   53151.148777             0.007069         0.015684      0.001237
# std     3046.944011             0.023523         0.037810      0.030400
# min    49271.000000             0.000900         0.002400      0.000000
# 25%    50433.000000             0.002100         0.004900      0.000000
# 50%    52535.000000             0.003600         0.008700      0.000100
# 75%    55525.000000             0.006300         0.015700      0.000200
# max    59884.000000             0.613100         1.000000      1.000000
#
#        volume_score
# count   2413.000000
# mean       0.001485
# std        0.027115
# min        0.000000
# 25%        0.000000
# 50%        0.000100
# 75%        0.000300
# max        1.000000

# %%
filtered_hourly_bots = hourly_bots[
    hourly_bots['bot_suspicion_score'] >
    hourly_bots['bot_suspicion_score'].quantile(0.7)
]
filtered_hourly_bots
# Out:
#       user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 76      49273               0.6131           0.0327        1.0000
# 253     49351               0.5278           0.0201        0.9909
# 440     51656               0.4119           1.0000        0.0007
# 13      49575               0.3799           0.9319        0.0000
# 252     49291               0.3300           0.0226        0.4993
# ...       ...                  ...              ...           ...
# 1642    51179               0.0062           0.0153        0.0002
# 641     49676               0.0062           0.0154        0.0001
# 1476    50470               0.0062           0.0154        0.0001
# 2270    56969               0.0062           0.0154        0.0001
# 2248    58496               0.0062           0.0149        0.0005
#
#       volume_score labels
# 76          1.0000     []
# 253         0.6171     []
# 440         0.0579     []
# 13          0.0357     []
# 252         0.6058     []
# ...            ...    ...
# 1642        0.0002     []
# 641         0.0003     []
# 1476        0.0000     []
# 2270        0.0000     []
# 2248        0.0002     []
#
# [723 rows x 6 columns]

# %% [markdown]
# ## Hipótese 3: Usuários que compartilham mensagens com pouca variação
# ![hourly](../../images/metronome.png)

# %%
G_metronome = load_graph_by_edge(driver, 'METRONOME_SIMILAR')

metronome_bots = rank_bot_suspicion(G_metronome) 
metronome_bots
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 3, column: 16, offset: 61} for query: '\n        MATCH (n)-[r:METRONOME_SIMILAR]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function. ('id' has been replaced by 'elementId or consider using an application-generated id')} {position: line: 4, column: 16, offset: 127} for query: '\n        MATCH (n)-[r:METRONOME_SIMILAR]->(m)\n        RETURN id(n) AS source_id, properties(n) AS source_props,\n               id(m) AS target_id, properties(m) AS target_props,\n               properties(r) AS edge_props\n    '
#       user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 153     51903               0.8308           0.8351        0.7418
# 26      49616               0.8289           0.8298        0.7459
# 167     52202               0.8289           0.8296        0.7461
# 49      49916               0.8289           0.8297        0.7459
# 68      50241               0.8288           0.8295        0.7461
# ...       ...                  ...              ...           ...
# 2413    50968               0.3092           0.7712        0.0000
# 2481    58709               0.3092           0.7712        0.0000
# 2480    56240               0.3092           0.7712        0.0000
# 2339    50023               0.2594           0.6449        0.0000
# 2343    54939               0.1765           0.4394        0.0000
#
#       volume_score labels
# 153         1.0000     []
# 26          0.9930     []
# 167         0.9930     []
# 49          0.9929     []
# 68          0.9930     []
# ...            ...    ...
# 2413        0.0037     []
# 2481        0.0037     []
# 2480        0.0037     []
# 2339        0.0072     []
# 2343        0.0036     []
#
# [2485 rows x 6 columns]

# %%
metronome_bots.describe()
# Out:
#             user_id  bot_suspicion_score  centrality_rank  clique_score  \
# count   2485.000000          2485.000000      2485.000000   2485.000000
# mean   52298.164990             0.729997         0.771160      0.743526
# std     2581.283957             0.064036         0.033537      0.055701
# min    49271.000000             0.176500         0.434800      0.000000
# 25%    50180.000000             0.697800         0.757100      0.727100
# 50%    51556.000000             0.736900         0.770700      0.747400
# 75%    53755.000000             0.780100         0.789300      0.764100
# max    59734.000000             0.830800         1.000000      1.000000
#
#        volume_score
# count    2485.00000
# mean        0.62061
# std         0.26652
# min         0.00360
# 25%         0.44270
# 50%         0.66580
# 75%         0.85880
# max         1.00000

# %%
filtered_metronome_bots = metronome_bots[
    metronome_bots['bot_suspicion_score'] >
    metronome_bots['bot_suspicion_score'].quantile(0.7)
]
filtered_metronome_bots
# Out:
#       user_id  bot_suspicion_score  centrality_rank  clique_score  \
# 153     51903               0.8308           0.8351        0.7418
# 26      49616               0.8289           0.8298        0.7459
# 167     52202               0.8289           0.8296        0.7461
# 49      49916               0.8289           0.8297        0.7459
# 68      50241               0.8288           0.8295        0.7461
# ...       ...                  ...              ...           ...
# 1188    54313               0.7756           0.7729        0.7103
# 1168    50257               0.7756           0.7659        0.7224
# 2038    50749               0.7756           0.7619        0.7442
# 1928    51220               0.7755           0.7926        0.7564
# 2435    51946               0.7755           0.7805        0.6956
#
#       volume_score labels
# 153         1.0000     []
# 26          0.9930     []
# 167         0.9930     []
# 49          0.9929     []
# 68          0.9930     []
# ...            ...    ...
# 1188        0.9117     []
# 1168        0.9013     []
# 2038        0.8656     []
# 1928        0.7793     []
# 2435        0.9253     []
#
# [745 rows x 6 columns]

# %% [markdown]
# ## Avaliando Semelhança entre Técnicas de Detecção

# %%
metronome_susp = set(filtered_metronome_bots['user_id'])
hourly_susp = set(filtered_hourly_bots['user_id'])
rapid_susp = set(filtered_rapid_bots['user_id'])

# %%
overlap_mh = metronome_susp & hourly_susp
overlap_mr = metronome_susp & rapid_susp
overlap_hr = hourly_susp & rapid_susp

len(overlap_mh), len(overlap_mr), len(overlap_hr)
# Out:
# (153, 32, 122)

# %%
def jaccard(a, b):
    return len(a & b) / len(a | b) if (a | b) else 0

j12 = jaccard(metronome_susp, hourly_susp)
j13 = jaccard(metronome_susp, rapid_susp)
j23 = jaccard(hourly_susp, rapid_susp)

j12, j13, j23
# Out:
# (0.11634980988593156, 0.03764705882352941, 0.16531165311653118)

# %%
def overlap_ratio(a, b):
    return len(a & b) / min(len(a), len(b)) if min(len(a), len(b)) else 0

o12 = overlap_ratio(metronome_susp, hourly_susp)
o13 = overlap_ratio(metronome_susp, rapid_susp)
o23 = overlap_ratio(rapid_susp, hourly_susp)

o12, o13, o23
# Out:
# (0.21161825726141079, 0.23357664233576642, 0.8905109489051095)

# %%
highest_confident = metronome_susp & hourly_susp & rapid_susp
highest_confident
# Out:
# {49271,
#  49333,
#  49432,
#  49452,
#  49514,
#  49519,
#  49589,
#  49645,
#  49654,
#  49727,
#  49834,
#  49862,
#  49864,
#  50004,
#  50009,
#  50011,
#  50056,
#  50112,
#  50136,
#  50281,
#  50574,
#  50585,
#  51089,
#  51662,
#  52859,
#  52883,
#  52896,
#  52934,
#  54055}
